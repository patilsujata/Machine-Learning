# %% [markdown]
# ### Pandas Visual Analysis
# pip install pandas_visual_analysis

# %%
import seaborn as sns

# %%
print(sns.get_dataset_names())
# Out:
# ['anagrams', 'anscombe', 'attention', 'brain_networks', 'car_crashes', 'diamonds', 'dots', 'exercise', 'flights', 'fmri', 'gammas', 'geyser', 'iris', 'mpg', 'penguins', 'planets', 'taxis', 'tips', 'titanic']

# %%
df=sns.load_dataset('titanic')

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
#!pip install pandas_visual_analysis
# Out:
# Collecting pandas_visual_analysis
#   Downloading pandas_visual_analysis-0.0.4-py3-none-any.whl (34 kB)
# Requirement already satisfied: ipywidgets>=7.5.1 in c:\users\admin\anaconda3\lib\site-packages (from pandas_visual_analysis) (7.6.5)
# Requirement already satisfied: pandas>=1.1.0 in c:\users\admin\anaconda3\lib\site-packages (from pandas_visual_analysis) (1.4.2)
# Requirement already satisfied: setuptools>=49.2.0 in c:\users\admin\anaconda3\lib\site-packages (from pandas_visual_analysis) (60.10.0)
# Collecting blinker>=1.4
#   Downloading blinker-1.4.tar.gz (111 kB)
# Requirement already satisfied: plotly>=4.10.0 in c:\users\admin\anaconda3\lib\site-packages (from pandas_visual_analysis) (5.6.0)
# Requirement already satisfied: numpy>=1.19.1 in c:\users\admin\anaconda3\lib\site-packages (from pandas_visual_analysis) (1.21.5)
# Requirement already satisfied: ipython>=4.0.0 in c:\users\admin\anaconda3\lib\site-packages (from ipywidgets>=7.5.1->pandas_visual_analysis) (8.2.0)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in c:\users\admin\anaconda3\lib\site-packages (from ipywidgets>=7.5.1->pandas_visual_analysis) (1.0.0)
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\admin\anaconda3\lib\site-packages (from ipywidgets>=7.5.1->pandas_visual_analysis) (5.1.1)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in c:\users\admin\anaconda3\lib\site-packages (from ipywidgets>=7.5.1->pandas_visual_analysis) (3.5.2)
# Requirement already satisfied: nbformat>=4.2.0 in c:\users\admin\anaconda3\lib\site-packages (from ipywidgets>=7.5.1->pandas_visual_analysis) (5.3.0)
# Requirement already satisfied: ipykernel>=4.5.1 in c:\users\admin\anaconda3\lib\site-packages (from ipywidgets>=7.5.1->pandas_visual_analysis) (6.9.1)
# Requirement already satisfied: ipython-genutils~=0.2.0 in c:\users\admin\anaconda3\lib\site-packages (from ipywidgets>=7.5.1->pandas_visual_analysis) (0.2.0)
# Requirement already satisfied: nest-asyncio in c:\users\admin\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5.1->pandas_visual_analysis) (1.5.5)
# Requirement already satisfied: matplotlib-inline<0.2.0,>=0.1.0 in c:\users\admin\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5.1->pandas_visual_analysis) (0.1.2)
# Requirement already satisfied: jupyter-client<8.0 in c:\users\admin\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5.1->pandas_visual_analysis) (6.1.12)
# Requirement already satisfied: tornado<7.0,>=4.2 in c:\users\admin\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5.1->pandas_visual_analysis) (6.1)
# Requirement already satisfied: debugpy<2.0,>=1.0.0 in c:\users\admin\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5.1->pandas_visual_analysis) (1.5.1)
# Requirement already satisfied: pickleshare in c:\users\admin\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets>=7.5.1->pandas_visual_analysis) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\admin\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets>=7.5.1->pandas_visual_analysis) (3.0.20)
# Requirement already satisfied: stack-data in c:\users\admin\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets>=7.5.1->pandas_visual_analysis) (0.2.0)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\admin\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets>=7.5.1->pandas_visual_analysis) (2.11.2)
# Requirement already satisfied: decorator in c:\users\admin\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets>=7.5.1->pandas_visual_analysis) (5.1.1)
# Requirement already satisfied: backcall in c:\users\admin\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets>=7.5.1->pandas_visual_analysis) (0.2.0)
# Requirement already satisfied: colorama in c:\users\admin\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets>=7.5.1->pandas_visual_analysis) (0.4.4)
# Requirement already satisfied: jedi>=0.16 in c:\users\admin\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets>=7.5.1->pandas_visual_analysis) (0.18.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\admin\anaconda3\lib\site-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets>=7.5.1->pandas_visual_analysis) (0.8.3)
# Requirement already satisfied: jupyter-core>=4.6.0 in c:\users\admin\anaconda3\lib\site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets>=7.5.1->pandas_visual_analysis) (4.9.2)
# Requirement already satisfied: python-dateutil>=2.1 in c:\users\admin\anaconda3\lib\site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets>=7.5.1->pandas_visual_analysis) (2.8.2)
# Requirement already satisfied: pyzmq>=13 in c:\users\admin\anaconda3\lib\site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets>=7.5.1->pandas_visual_analysis) (22.3.0)
# Requirement already satisfied: pywin32>=1.0 in c:\users\admin\anaconda3\lib\site-packages (from jupyter-core>=4.6.0->jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets>=7.5.1->pandas_visual_analysis) (302)
# Requirement already satisfied: fastjsonschema in c:\users\admin\anaconda3\lib\site-packages (from nbformat>=4.2.0->ipywidgets>=7.5.1->pandas_visual_analysis) (2.15.1)
# Requirement already satisfied: jsonschema>=2.6 in c:\users\admin\anaconda3\lib\site-packages (from nbformat>=4.2.0->ipywidgets>=7.5.1->pandas_visual_analysis) (4.4.0)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\admin\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets>=7.5.1->pandas_visual_analysis) (21.4.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\admin\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets>=7.5.1->pandas_visual_analysis) (0.18.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\admin\anaconda3\lib\site-packages (from pandas>=1.1.0->pandas_visual_analysis) (2021.3)
# Requirement already satisfied: six in c:\users\admin\anaconda3\lib\site-packages (from plotly>=4.10.0->pandas_visual_analysis) (1.16.0)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\admin\anaconda3\lib\site-packages (from plotly>=4.10.0->pandas_visual_analysis) (8.0.1)
# Requirement already satisfied: wcwidth in c:\users\admin\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets>=7.5.1->pandas_visual_analysis) (0.2.5)
# Requirement already satisfied: notebook>=4.4.1 in c:\users\admin\anaconda3\lib\site-packages (from widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas_visual_analysis) (6.4.8)
# Requirement already satisfied: prometheus-client in c:\users\admin\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas_visual_analysis) (0.13.1)
# Requirement already satisfied: jinja2 in c:\users\admin\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas_visual_analysis) (2.11.3)
# Requirement already satisfied: nbconvert in c:\users\admin\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas_visual_analysis) (6.4.4)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\admin\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas_visual_analysis) (0.13.1)
# Requirement already satisfied: Send2Trash>=1.8.0 in c:\users\admin\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas_visual_analysis) (1.8.0)
# Requirement already satisfied: argon2-cffi in c:\users\admin\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas_visual_analysis) (21.3.0)
# Requirement already satisfied: pywinpty>=1.1.0 in c:\users\admin\anaconda3\lib\site-packages (from terminado>=0.8.3->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas_visual_analysis) (2.0.2)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\admin\anaconda3\lib\site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas_visual_analysis) (21.2.0)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\admin\anaconda3\lib\site-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas_visual_analysis) (1.15.0)
# Requirement already satisfied: pycparser in c:\users\admin\anaconda3\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas_visual_analysis) (2.21)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\admin\anaconda3\lib\site-packages (from jinja2->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas_visual_analysis) (2.0.1)
# Requirement already satisfied: entrypoints>=0.2.2 in c:\users\admin\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas_visual_analysis) (0.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\admin\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas_visual_analysis) (1.5.0)
# Requirement already satisfied: defusedxml in c:\users\admin\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas_visual_analysis) (0.7.1)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\admin\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas_visual_analysis) (0.8.4)
# Requirement already satisfied: beautifulsoup4 in c:\users\admin\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas_visual_analysis) (4.11.1)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in c:\users\admin\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas_visual_analysis) (0.5.13)
# Requirement already satisfied: testpath in c:\users\admin\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas_visual_analysis) (0.5.0)
# Requirement already satisfied: jupyterlab-pygments in c:\users\admin\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas_visual_analysis) (0.1.2)
# Requirement already satisfied: bleach in c:\users\admin\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas_visual_analysis) (4.1.0)
# Requirement already satisfied: soupsieve>1.2 in c:\users\admin\anaconda3\lib\site-packages (from beautifulsoup4->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas_visual_analysis) (2.3.1)
# Requirement already satisfied: webencodings in c:\users\admin\anaconda3\lib\site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas_visual_analysis) (0.5.1)
# Requirement already satisfied: packaging in c:\users\admin\anaconda3\lib\site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas_visual_analysis) (21.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\admin\anaconda3\lib\site-packages (from packaging->bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas_visual_analysis) (3.0.4)
# Requirement already satisfied: pure-eval in c:\users\admin\anaconda3\lib\site-packages (from stack-data->ipython>=4.0.0->ipywidgets>=7.5.1->pandas_visual_analysis) (0.2.2)
# Requirement already satisfied: asttokens in c:\users\admin\anaconda3\lib\site-packages (from stack-data->ipython>=4.0.0->ipywidgets>=7.5.1->pandas_visual_analysis) (2.0.5)
# Requirement already satisfied: executing in c:\users\admin\anaconda3\lib\site-packages (from stack-data->ipython>=4.0.0->ipywidgets>=7.5.1->pandas_visual_analysis) (0.8.3)
# Building wheels for collected packages: blinker
#   Building wheel for blinker (setup.py): started
#   Building wheel for blinker (setup.py): finished with status 'done'
#   Created wheel for blinker: filename=blinker-1.4-py3-none-any.whl size=13478 sha256=4ca22f30dd7dde5cf3e02ae057f3f439ce98f764fd1b76a253de2c557df775df
#   Stored in directory: c:\users\admin\appdata\local\pip\cache\wheels\50\93\f8\4f0a42a03a06626d675f13907b6982ad5ecff383530af5a900
# Successfully built blinker
# Installing collected packages: blinker, pandas-visual-analysis
# Successfully installed blinker-1.4 pandas-visual-analysis-0.0.4

# %%
from pandas_visual_analysis import VisualAnalysis

# %%
df.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
VisualAnalysis(df)
# Out:
# VBox(children=(ToggleButtons(_dom_classes=('layout-69182639efc04ab8b1155a1d7d87f2fd',), description='Selection…
